# %% [markdown]
# <a href="https://colab.research.google.com/github/srikanthbabu/pyspark/blob/main/Colab_PySpark_One_Click.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

SPARK_VERSION = "3.5.1"
SPARK_DIR = f"/content/drive/MyDrive/colab_spark/spark-{SPARK_VERSION}-bin-hadoop3"
JAVA_HOME = "/usr/lib/jvm/java-11-openjdk-amd64"

# !apt-get install -y openjdk-11-jdk-headless

import os
if not os.path.exists(SPARK_DIR):
    # !wget -q https://downloads.apache.org/spark/spark-{SPARK_VERSION}/spark-{SPARK_VERSION}-bin-hadoop3.tgz -O /content/spark.tgz
    # !mkdir -p /content/drive/MyDrive/colab_spark
    # !tar -xzf /content/spark.tgz -C /content/drive/MyDrive/colab_spark/

os.environ["JAVA_HOME"] = JAVA_HOME
os.environ["SPARK_HOME"] = SPARK_DIR
os.environ["PATH"] += f":{SPARK_DIR}/bin:{JAVA_HOME}/bin"

# !chmod -R 755 {SPARK_DIR}

# !pip install -q pyspark
print("PySpark is ready!")
